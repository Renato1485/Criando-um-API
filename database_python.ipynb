# %% [markdown]
# <a href="https://colab.research.google.com/github/Renato1485/Criando-um-API/blob/main/database_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level  ... company_location company_size
# 0     2025.0               SE  ...               US            M
# 1     2025.0               SE  ...               US            M
# 2     2025.0               MI  ...               AU            M
# 3     2025.0               MI  ...               AU            M
# 4     2025.0               EN  ...               US            M
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("Número de linhas é: ", linhas)
print("Número de colunas é: ", colunas)
# Out:
# Número de linhas é:  133349
# Número de colunas é:  11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
renomear_coluna = {
    'ano_trabalho': 'ano',
    'nivel_experiencia': 'senhoridade',
    'tipo_emprego': 'contrato',
    'cargo': 'cargo',
    'salario': 'salario',
    'moeda_salario': 'moeda',
    'salario_em_usd': 'usd',
    'residencia_empregado': 'residencia',
    'taxa_remoto': 'remoto',
    'localizacao_empresa': 'empresa',
    'tamanho_empresa': 'tamanho_empresa'
}

df.rename(columns=renomear_coluna, inplace=True)
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
traduzir_coluna = {
    'work_year': 'ano',
    'experience_level': 'senhoridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency':'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df.rename(columns=traduzir_coluna, inplace=True)
df.columns
# Out:
# Index(['ano', 'senhoridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["ano"].value_counts()
# Out:
# ano
# 2024.0    62240
# 2025.0    60627
# 2023.0     8521
# 2022.0     1660
# 2021.0      216
# 2020.0       75
# Name: count, dtype: int64

# %%
df["senhoridade"].value_counts()
# Out:
# senhoridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["cargo"].value_counts()
# Out:
# cargo
# Data Scientist                     17314
# Software Engineer                  15007
# Data Engineer                      14868
# Data Analyst                       12381
# Engineer                            9456
#                                    ...
# Quantitative Research Analyst          1
# Data Science Tech Lead                 1
# Staff Machine Learning Engineer        1
# Principal Data Architect               1
# Cloud Data Architect                   1
# Name: count, Length: 390, dtype: int64

# %%
df["salario"].value_counts()
# Out:
# salario
# 160000     2466
# 110000     2262
# 150000     2189
# 180000     1840
# 100000     1839
#            ...
# 165220        1
# 208775        1
# 1450000       1
# 1335000       1
# 19000         1
# Name: count, Length: 11234, dtype: int64

# %%
df["moeda"].value_counts()
# Out:
# moeda
# USD    126140
# GBP      3597
# EUR      2602
# CAD       548
# INR       139
# PLN        94
# CHF        45
# AUD        32
# PHP        29
# BRL        23
# SGD        22
# TWD        17
# JPY        14
# HUF         9
# CZK         6
# DKK         5
# NOK         5
# ZAR         5
# MXN         4
# TRY         4
# ILS         3
# THB         2
# SEK         1
# NZD         1
# HKD         1
# CLP         1
# Name: count, dtype: int64

# %%
df["usd"].value_counts()
# Out:
# usd
# 160000    2447
# 110000    2203
# 150000    2167
# 180000    1828
# 100000    1762
#           ...
# 26005        1
# 95770        1
# 28369        1
# 412000       1
# 148261       1
# Name: count, Length: 12421, dtype: int64

# %%
df["residencia"].value_counts()
# Out:
# residencia
# US    119579
# CA      5238
# GB      3711
# AU       517
# NL       404
#        ...
# KW         1
# AS         1
# CN         1
# IQ         1
# JE         1
# Name: count, Length: 102, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["empresa"].value_counts()
# Out:
# empresa
# US    119641
# CA      5239
# GB      3719
# AU       522
# NL       404
#        ...
# IR         1
# BS         1
# IQ         1
# CN         1
# MD         1
# Name: count, Length: 95, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
senhoridade = {
    'SE': 'Senior',
    'MI': 'Junior',
    'EN': 'Pleno',
    'EX': 'Executivo'
}

df["senhoridade"] = df["senhoridade"].replace(senhoridade)
df["senhoridade"].value_counts()
# Out:
# senhoridade
# Senior       77241
# Junior       40465
# Pleno        12443
# Executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'Tempo integral',
    'PT': 'Tempo parcial',
    'FL': 'Freelancer',
    'CT': 'Contrato'
}

df["contrato"] = df["contrato"].replace(contrato)
df["contrato"].value_counts()
# Out:
# contrato
# Tempo integral    132563
# Contrato             394
# Tempo parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df["tamanho_empresa"] = df["tamanho_empresa"].replace(tamanho_empresa)
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
remoto = {
    '0': 'Presencial',
    '50': 'Hibrido',
    '100': 'Remoto'
}

df["remoto"] = df["remoto"].replace(remoto)
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senhoridade        contrato  ... remoto  empresa tamanho_empresa
# 0  2025.0      Senior  Tempo integral  ...    100       US           Médio
# 1  2025.0      Senior  Tempo integral  ...    100       US           Médio
# 2  2025.0      Junior  Tempo integral  ...      0       AU           Médio
# 3  2025.0      Junior  Tempo integral  ...      0       AU           Médio
# 4  2025.0       Pleno  Tempo integral  ...      0       US           Médio
#
# [5 rows x 11 columns]

# %%
df.describe(include='object')
# Out:
#        senhoridade        contrato  ... empresa tamanho_empresa
# count       133349          133349  ...  133349          133349
# unique           4               4  ...      95               3
# top         Senior  Tempo integral  ...      US           Médio
# freq         77241          132563  ...  119641          129561
#
# [4 rows x 7 columns]

# %%
df.describe()
# Out:
#                  ano       salario            usd         remoto
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.isnull()
# Out:
#           ano  senhoridade  contrato  ...  remoto  empresa  tamanho_empresa
# 0       False        False     False  ...   False    False            False
# 1       False        False     False  ...   False    False            False
# 2       False        False     False  ...   False    False            False
# 3       False        False     False  ...   False    False            False
# 4       False        False     False  ...   False    False            False
# ...       ...          ...       ...  ...     ...      ...              ...
# 133344  False        False     False  ...   False    False            False
# 133345  False        False     False  ...   False    False            False
# 133346  False        False     False  ...   False    False            False
# 133347  False        False     False  ...   False    False            False
# 133348  False        False     False  ...   False    False            False
#
# [133349 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# ano                10
# senhoridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# [2025.   nan 2024. 2022. 2023. 2020. 2021.]

# %%
df[df.isnull().any(axis = 1)]
# Out:
#         ano senhoridade        contrato  ... remoto  empresa tamanho_empresa
# 5588    NaN      Senior  Tempo integral  ...      0       US           Médio
# 59692   NaN      Junior  Tempo integral  ...      0       DE           Médio
# 59710   NaN       Pleno  Tempo integral  ...      0       US           Médio
# 59759   NaN      Senior  Tempo integral  ...      0       US           Médio
# 59789   NaN      Senior  Tempo integral  ...      0       US           Médio
# 131000  NaN      Senior  Tempo integral  ...      0       US           Médio
# 131006  NaN      Senior  Tempo integral  ...      0       US           Médio
# 133054  NaN       Pleno  Tempo integral  ...    100       MY          Grande
# 133281  NaN      Junior  Tempo integral  ...    100       PL          Grande
# 133317  NaN      Junior  Tempo integral  ...     50       US          Grande
#
# [10 rows x 11 columns]

# %%
import numpy as np
#criação de dataframe teste
df_salarios = pd.DataFrame({
    'nome': ["Ana", "Paula", "Ricardo", "Paulo", "Val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
    })
#calcula a média e arredonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
#calcula a mediana
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
df_salarios
# Out:
#       nome   salario  salario_media
# 0      Ana    4000.0         4000.0
# 1    Paula       NaN         5000.0
# 2  Ricardo    5000.0         5000.0
# 3    Paulo       NaN         5000.0
# 4      Val  100000.0       100000.0

# %%
df_temperaturas = pd.DataFrame({
    'dias': ["segunda", "terça", "quarta", "quinta", "sexta"],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas['preenchido_ffill'] = df_temperaturas['temperatura'].ffill()
df_temperaturas
# Out:
#       dias  temperatura  preenchido_ffill
# 0  segunda         30.0              30.0
# 1    terça          NaN              30.0
# 2   quarta          NaN              30.0
# 3   quinta         28.0              28.0
# 4    sexta         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ["Ana", "Paula", "Ricardo", "Paulo", "Val"],
    'cidade': ["São Paulo", np.nan, "curitiva", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna("Não informada")
df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Paula        NaN     Não informada
# 2  Ricardo   curitiva          curitiva
# 3    Paulo        NaN     Não informada
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senhoridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senhoridade        contrato  ... remoto  empresa tamanho_empresa
# 0  2025.0      Senior  Tempo integral  ...    100       US           Médio
# 1  2025.0      Senior  Tempo integral  ...    100       US           Médio
# 2  2025.0      Junior  Tempo integral  ...      0       AU           Médio
# 3  2025.0      Junior  Tempo integral  ...      0       AU           Médio
# 4  2025.0       Pleno  Tempo integral  ...      0       US           Médio
#
# [5 rows x 11 columns]

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senhoridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
#converter o Dtype de flout para int
df_limpo = df_limpo.assign(ano = df_limpo["ano"].astype("int64"))

# %%
#criação de gráfico
df_limpo['senhoridade'].value_counts().plot(kind='bar', title='Senhoridade')
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#criação de gráfico com salários médio anual em dólar
sns.barplot(data=df_limpo, x='senhoridade', y='usd')
# Out:
# <Axes: xlabel='senhoridade', ylabel='usd'>

# %%
#configurando o gráfico
plt.figure(figsize=(10,6))
sns.barplot(data=df_limpo, x='senhoridade', y='usd')
plt.title('Salário médio por senhoridade')
plt.xlabel('Senhoridade')
plt.ylabel('Salário médio anual(usd)')
plt.show()

# %%
df_limpo.groupby('senhoridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senhoridade
# Executivo    202027.667813
# Senior       172850.838301
# Junior       143044.845979
# Pleno         99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senhoridade')['usd'].mean().sort_values(ascending=True).index #função para alterar o gráfico do menor para o maior ou contrário
ordem
# Out:
# Index(['Pleno', 'Junior', 'Senior', 'Executivo'], dtype='object', name='senhoridade')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_limpo, x='senhoridade', y='usd', order=ordem)
plt.title('Salário médio por senhoridade')
plt.xlabel('Senhoridade')
plt.ylabel('Salário médio anual(usd)')
plt.show()

# %%
plt.figure(figsize=(10,5)) #largura e altura do gráfito
sns.histplot(df_limpo['usd'], bins=50, kde=True)# bins=50, é a largura das linhas do gráfico, e o True é a linha azul que acompanha as colunas
plt.title('Distribuição salarial')
plt.xlabel('Salário anual(usd)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = df_limpo['usd'])
plt.title('Boxplot salarial')
plt.xlabel('Salário anual(usd)')
plt.show()

# %%
ordem_senhoridade = ['Junior', 'Pleno', 'Senior', 'Executivo']
plt.figure(figsize=(8,5))
sns.boxplot(x = df_limpo['senhoridade'], y = df_limpo['usd'], order = ordem_senhoridade)
plt.title('Boxplot salarial por senhoridade')
plt.xlabel('senhoridade')
plt.show()

# %%
ordem_senhoridade = ['Junior', 'Pleno', 'Senior', 'Executivo']
plt.figure(figsize=(8,5))
sns.boxplot(x = df_limpo['senhoridade'], y = df_limpo['usd'], order = ordem_senhoridade, palette='Set2', hue='senhoridade', data=df_limpo)
plt.title('Boxplot salarial por senhoridade')
plt.xlabel('senhoridade')
plt.show()

# %%
import plotly.express as px

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="498c9573-44a9-42d8-b194-389a9b3ee093" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("498c9573-44a9-42d8-b194-389a9b3ee093")) {                    Plotly.newPlot(                        "498c9573-44a9-42d8-b194-389a9b3ee093",                        [{"alignmentgroup":"True","hovertemplate":"Senhoridade=%{x}\u003cbr\u003eSalário Médio Anual (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Senior","Senior","Junior","Junior","Pleno","Pleno","Senior","Senior","Junior","Junior","Junior","Junior","Pleno","Pleno","Senior","Senior","Junior","Junior","Executivo","Executivo","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Pleno","Pleno","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Pleno","Pleno","Pleno","Pleno","Pleno","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Pleno","Pleno","Senior","Senior","Senior","Senior","Junior","Junior","Pleno","Pleno","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Pleno","Pleno","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Pleno","Pleno","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Pleno","Pleno","Senior","Senior","Senior","Senior","Junior","Junior","Executivo","Executivo","Senior","Senior","Senior","Senior","Executivo","Executivo","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Executivo","Executivo","Pleno","Pleno","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Executivo","Executivo","Pleno","Pleno","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Pleno","Pleno","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Junior","Junior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Junior","Junior","Junior","Executivo","Executivo","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Junior","Junior","Senior","Senior","Senior","Senior","Senior","Senior","Senior", ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem, #criando gráfico pizza
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição por tipo de trabalho remoto')
fig.show()
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Renat\.vscode\extensions\ms-python.python-2025.12.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\basedatatypes.py", line 3420, in show
#     return pio.show(self, *args, **kwargs)
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\io\_renderers.py", line 415, in show
#     raise ValueError(
#         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     )
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem, #criando gráfico pizza
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição por tipo de trabalho remoto',
             hole=0.5) #Criar um espaço dentro do gráfico (tipo rosquinhas)
fig.show()
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Renat\.vscode\extensions\ms-python.python-2025.12.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 9, in <module>
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\basedatatypes.py", line 3420, in show
#     return pio.show(self, *args, **kwargs)
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\io\_renderers.py", line 415, in show
#     raise ValueError(
#         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     )
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem, #criando gráfico pizza
             names='tipo_trabalho',
             values='quantidade',
             title='Distribuição por tipo de trabalho remoto',
             hole=0.5) #Criar um espaço dentro do gráfico (tipo rosquinhas)
fig.update_traces(textinfo='percent+label') #adicionar texto no gráfico
fig.show()
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Renat\.vscode\extensions\ms-python.python-2025.12.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 10, in <module>
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\basedatatypes.py", line 3420, in show
#     return pio.show(self, *args, **kwargs)
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Renat\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\io\_renderers.py", line 415, in show
#     raise ValueError(
#         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     )
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
